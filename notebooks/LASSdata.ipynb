# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/csuee1102-class/blob/main/notebooks/LASSdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# %%
res = requests.get("https://pm25.lass-net.org/data/history.php?device_id=74DA38EBF902")
data = json.loads(res.text)

# %%
AirBox = map(lambda x: x.get(list(x.keys())[0]) , data['feeds'][0]['AirBox'])
s_t0 = map(lambda x: {"s_t0":x.get("s_t0", ""), "timestamp": x.get("timestamp")}, AirBox)

# %%
print(list(s_t0))
# Out:
# [{'s_t0': 27.87, 'timestamp': '2022-05-24T15:27:03Z'}, {'s_t0': 27.87, 'timestamp': '2022-05-24T15:33:10Z'}, {'s_t0': 27.87, 'timestamp': '2022-05-24T15:39:17Z'}, {'s_t0': 27.87, 'timestamp': '2022-05-24T15:45:24Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T15:51:31Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T15:57:37Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T16:03:44Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T16:09:51Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T16:16:00Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T16:22:07Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T16:28:14Z'}, {'s_t0': 27.62, 'timestamp': '2022-05-24T16:34:21Z'}, {'s_t0': 27.75, 'timestamp': '2022-05-24T16:40:27Z'}, {'s_t0': 27.62, 'timestamp': '2022-05-24T16:46:34Z'}, {'s_t0': 27.62, 'timestamp': '2022-05-24T16:52:41Z'}, {'s_t0': 27.62, 'timestamp': '2022-05-24T16:58:48Z'}, {'s_t0': 27.62, 'timestamp': '2022-05-24T17:07:47Z'}, {'s_t0': 27.5, 'timestamp': '2022-05-24T17:13:53Z'}, {'s_t0': 27.5, 'timestamp'
# ...

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
for key,value in data.items():
  print("{}:{}".format(key,value))
  if key=="feeds":
    print(type(value))
# Out:
# device_id:74DA38EBF902
# source:history by IIS-NRL
# num_of_records:1583
# ...

# %%
data = map(lambda x: (x.get("timestamp"), x.get("s_d0",""), x.get("s_h0",""), x.get("s_t0", "")), AirBox)

# %%
print(type(data))
# Out:
# <class 'map'>

# %%
import json 
import pandas as pd
from urllib import request
#氣象局-鄉鎮天氣預報-台灣未來1週天氣預報
#https://opendata.cwb.gov.tw/dataset/statisticDays/F-D0047-091
url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-D0047-091?Authorization=CWB-413ECD83-6DED-44E7-AEE1-0A75A6394562&downloadType=WEB&format=JSON'
data = request.urlopen(url).read().decode("utf-8")
print (json.loads(data))
# Out:
# {'cwbopendata': {'@xmlns': 'urn:cwb:gov:tw:cwbcommon:0.1', 'identifier': 'acac8ed8-4ba6-4a8a-85f6-a1c089fd3c92', 'sender': 'weather@cwb.gov.tw', 'sent': '2022-05-31T22:55:06+08:00', 'status': 'Actual', 'scope': 'Public', 'msgType': 'Issue', 'dataid': 'D0047-091', 'source': 'MFC', 'dataset': {'datasetInfo': {'datasetDescription': '臺灣各縣市鄉鎮未來1週逐12小時天氣預報', 'datasetLanguage': 'zh-TW', 'issueTime': '2022-05-31T23:00:00+08:00', 'validTime': {'startTime': '2022-06-01T00:00:00+08:00', 'endTime': '2022-06-08T23:00:00+08:00'}, 'update': '2022-05-31T22:55:06+08:00'}, 'locations': {'locationsName': '台灣', 'location': [{'locationName': '連江縣', 'geocode': '09007000', 'lat': '26.154204', 'lon': '119.929303', 'weatherElement': [{'elementName': 'T', 'description': '平均溫度', 'time': [{'startTime': '2022-06-01T00:00:00+08:00', 'endTime': '2022-06-01T06:00:00+08:00', 'elementValue': {'value': '21', 'measures': '攝氏度'}}, {'startTime': '2022-06-01T06:00:00+08:00', 'endTime': '2022-06-01T18:00:00+08:00', 'elemen
# ...
